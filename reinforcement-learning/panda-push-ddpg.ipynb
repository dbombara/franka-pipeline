# %%
import gymnasium as gym
import panda_gym

# %%
from stable_baselines3 import DDPG, HerReplayBuffer
from stable_baselines3.common.env_util import make_vec_env
import PIL
from stable_baselines3.common.logger import configure

# %%
env = make_vec_env('PandaPush-v3',n_envs=1, seed=98)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %%
tmp_path = "/tmp/sb3_log/"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Out:
# Logging to /tmp/sb3_log/

# %%
model = DDPG('MultiInputPolicy',
            env,
            verbose=0,
            replay_buffer_class=HerReplayBuffer)

# %%
model.set_logger(new_logger)

# %%
model.learn(total_timesteps=1e6)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.8     |
# |    ep_rew_mean     | -37.5    |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 920      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 151      |
# | train/             |          |
# |    actor_loss      | 0.107    |
# |    critic_loss     | 0.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1        |
# ---------------------------------
# /Users/davidbombara_1/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.compute_reward to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.compute_reward` for environment variables or `env.get_wrapper_attr('compute_reward')` that will search the reminding wrappers.
#   logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.9     |
# |    ep_rew_mean     | -43.8    |
# |    success_rate    | 0.125    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 286      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 351      |
# | train/             |          |
# |    actor_loss      | 0.196    |
# |    critic_loss     | 0.0298   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 201      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.9     |
# |    ep_rew_mean     | -45.8    |
# |    success_rate    | 0.0833   |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 244      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 551      |
# | train/             |          |
# |    actor_loss      | 0.297    |
# |    critic_loss     | 0.0321   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 401      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.9     |
# |    ep_rew_mean     | -43.8    |
# |    success_rate    | 0.125    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 233      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 702      |
# | train/             |          |
# |    actor_loss      | 0.272    |
# |    critic_loss     | 0.0178   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 552      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.1     |
# |    ep_rew_mean     | -45      |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 221      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 902      |
# | train/             |          |
# |    actor_loss      | 0.309    |
# |    critic_loss     | 0.0102   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 752      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.9     |
# |    ep_rew_mean     | -45.8    |
# |    success_rate    | 0.0833   |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 215      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1102     |
# | train/             |          |
# |    actor_loss      | 0.329    |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 952      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.5     |
# |    ep_rew_mean     | -46.4    |
# |    success_rate    | 0.0714   |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 210      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1302     |
# | train/             |          |
# |    actor_loss      | 0.267    |
# |    critic_loss     | 0.0229   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1152     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.9     |
# |    ep_rew_mean     | -46.9    |
# |    success_rate    | 0.0625   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 205      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1502     |
# | train/             |          |
# |    actor_loss      | 0.229    |
# |    critic_loss     | 0.0253   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.3     |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.0556   |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 199      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1702     |
# | train/             |          |
# |    actor_loss      | 0.18     |
# |    critic_loss     | 0.0147   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1552     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 199      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1902     |
# | train/             |          |
# |    actor_loss      | 0.238    |
# |    critic_loss     | 0.0146   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.7     |
# |    ep_rew_mean     | -46.6    |
# |    success_rate    | 0.0682   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 198      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2053     |
# | train/             |          |
# |    actor_loss      | 0.27     |
# |    critic_loss     | 0.051    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1903     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.9     |
# |    ep_rew_mean     | -45.8    |
# |    success_rate    | 0.0833   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 197      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2204     |
# | train/             |          |
# |    actor_loss      | 0.322    |
# |    critic_loss     | 0.0241   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.2     |
# |    ep_rew_mean     | -46.2    |
# |    success_rate    | 0.0769   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 196      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2404     |
# | train/             |          |
# |    actor_loss      | 0.362    |
# |    critic_loss     | 0.0179   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2254     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.5     |
# |    ep_rew_mean     | -46.4    |
# |    success_rate    | 0.0714   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 196      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2604     |
# | train/             |          |
# |    actor_loss      | 0.364    |
# |    critic_loss     | 0.0232   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2454     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.7     |
# |    ep_rew_mean     | -46.7    |
# |    success_rate    | 0.0667   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 196      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2804     |
# | train/             |          |
# |    actor_loss      | 0.431    |
# |    critic_loss     | 0.0179   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.9     |
# |    ep_rew_mean     | -46.9    |
# |    success_rate    | 0.0625   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 195      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 3004     |
# | train/             |          |
# |    actor_loss      | 0.518    |
# |    critic_loss     | 0.152    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2854     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47.1    |
# |    success_rate    | 0.0588   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 195      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 3204     |
# | train/             |          |
# |    actor_loss      | 0.566    |
# |    critic_loss     | 0.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.0694   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 194      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 3355     |
# | train/             |          |
# |    actor_loss      | 0.538    |
# |    critic_loss     | 0.0391   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3205     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -46.1    |
# |    success_rate    | 0.0789   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 192      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 3506     |
# | train/             |          |
# |    actor_loss      | 0.636    |
# |    critic_loss     | 0.0297   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3405     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.3     |
# |    ep_rew_mean     | -46.2    |
# |    success_rate    | 0.075    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 194      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 3706     |
# | train/             |          |
# |    actor_loss      | 0.759    |
# |    critic_loss     | 0.0387   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3556     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.5     |
# |    ep_rew_mean     | -46.4    |
# |    success_rate    | 0.0714   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 194      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 3906     |
# | train/             |          |
# |    actor_loss      | 0.881    |
# |    critic_loss     | 0.262    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3756     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.7     |
# |    ep_rew_mean     | -46.6    |
# |    success_rate    | 0.0682   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 194      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 4106     |
# | train/             |          |
# |    actor_loss      | 0.983    |
# |    critic_loss     | 0.0921   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3956     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.8     |
# |    ep_rew_mean     | -46.7    |
# |    success_rate    | 0.0652   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 194      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 4306     |
# | train/             |          |
# |    actor_loss      | 1.07     |
# |    critic_loss     | 0.178    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4156     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.5     |
# |    ep_rew_mean     | -46.4    |
# |    success_rate    | 0.0729   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 194      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 4461     |
# | train/             |          |
# |    actor_loss      | 1.04     |
# |    critic_loss     | 0.0807   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 194      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 4661     |
# | train/             |          |
# |    actor_loss      | 1.13     |
# |    critic_loss     | 0.0889   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4511     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 194      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 4861     |
# | train/             |          |
# |    actor_loss      | 1.18     |
# |    critic_loss     | 0.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4711     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 194      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 5061     |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.116    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4911     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 194      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 5212     |
# | train/             |          |
# |    actor_loss      | 1.33     |
# |    critic_loss     | 0.235    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5062     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 194      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 5412     |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.695    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5262     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 192      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 5563     |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.383    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5462     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 193      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 5763     |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.204    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5613     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 193      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 5963     |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.101    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5813     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -46      |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 193      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 6114     |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.161    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5964     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -45.5    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 192      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 6265     |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.0279   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6115     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -45.5    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 192      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 6465     |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6315     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -46      |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 192      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 6665     |
# | train/             |          |
# |    actor_loss      | 1.83     |
# |    critic_loss     | 0.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6515     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46       |
# |    ep_rew_mean     | -45.9    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 192      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.0238   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6666     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46       |
# |    ep_rew_mean     | -45.9    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 192      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | 1.82     |
# |    critic_loss     | 0.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6850     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.7     |
# |    ep_rew_mean     | -45.6    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 192      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 7173     |
# | train/             |          |
# |    actor_loss      | 1.82     |
# |    critic_loss     | 0.192    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.7     |
# |    ep_rew_mean     | -45.6    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 192      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 7373     |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 0.124    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7223     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44.1    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 192      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 7426     |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.0226   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7276     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44.1    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 192      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 7626     |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.134    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7476     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 192      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 7826     |
# | train/             |          |
# |    actor_loss      | 1.94     |
# |    critic_loss     | 0.189    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7676     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.2     |
# |    ep_rew_mean     | -45.1    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 191      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 8026     |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 0.311    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7876     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 191      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 8177     |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.0897   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8027     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 191      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 8377     |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 0.143    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8227     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 191      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 8577     |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.113    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8427     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 191      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 8777     |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 0.153    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8627     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.5    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 191      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 8928     |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.417    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8778     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.5    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 191      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 9128     |
# | train/             |          |
# |    actor_loss      | 2.21     |
# |    critic_loss     | 0.193    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8978     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44      |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 191      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 9279     |
# | train/             |          |
# |    actor_loss      | 2.3      |
# |    critic_loss     | 0.176    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9129     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44      |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 190      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 9479     |
# | train/             |          |
# |    actor_loss      | 2.28     |
# |    critic_loss     | 0.0591   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9329     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44      |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 190      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 9630     |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 0.0299   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9480     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44      |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 191      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 9830     |
# | train/             |          |
# |    actor_loss      | 2.35     |
# |    critic_loss     | 0.179    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9680     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.5    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 191      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 10030    |
# | train/             |          |
# |    actor_loss      | 2.41     |
# |    critic_loss     | 0.348    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.5    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 191      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 10230    |
# | train/             |          |
# |    actor_loss      | 2.4      |
# |    critic_loss     | 0.108    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10080    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.5    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 191      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 10430    |
# | train/             |          |
# |    actor_loss      | 2.51     |
# |    critic_loss     | 0.542    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10280    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.2     |
# |    ep_rew_mean     | -45      |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 191      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 10630    |
# | train/             |          |
# |    actor_loss      | 2.57     |
# |    critic_loss     | 0.369    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10480    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -45.5    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 191      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 10830    |
# | train/             |          |
# |    actor_loss      | 2.59     |
# |    critic_loss     | 0.297    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10680    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -45.5    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 191      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 11030    |
# | train/             |          |
# |    actor_loss      | 2.47     |
# |    critic_loss     | 0.397    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -45.5    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 191      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 11230    |
# | train/             |          |
# |    actor_loss      | 2.53     |
# |    critic_loss     | 0.152    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11080    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.3     |
# |    ep_rew_mean     | -46.2    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 191      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 11430    |
# | train/             |          |
# |    actor_loss      | 2.58     |
# |    critic_loss     | 0.311    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11280    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.3     |
# |    ep_rew_mean     | -46.2    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 191      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 11630    |
# | train/             |          |
# |    actor_loss      | 2.58     |
# |    critic_loss     | 0.452    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11480    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -45.5    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 191      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 11732    |
# | train/             |          |
# |    actor_loss      | 3.3      |
# |    critic_loss     | 1.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11631    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -45.5    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 192      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 11932    |
# | train/             |          |
# |    actor_loss      | 2.61     |
# |    critic_loss     | 0.693    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11782    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 192      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 12083    |
# | train/             |          |
# |    actor_loss      | 2.62     |
# |    critic_loss     | 0.409    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11933    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 192      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 12283    |
# | train/             |          |
# |    actor_loss      | 2.59     |
# |    critic_loss     | 0.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12133    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 192      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 12483    |
# | train/             |          |
# |    actor_loss      | 2.69     |
# |    critic_loss     | 0.938    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12333    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.5    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 192      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 12683    |
# | train/             |          |
# |    actor_loss      | 2.68     |
# |    critic_loss     | 0.846    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12533    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.6    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 192      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 12840    |
# | train/             |          |
# |    actor_loss      | 2.67     |
# |    critic_loss     | 0.636    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12690    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -46.6    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 192      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 13040    |
# | train/             |          |
# |    actor_loss      | 2.58     |
# |    critic_loss     | 0.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12890    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -46.1    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 192      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 13191    |
# | train/             |          |
# |    actor_loss      | 2.56     |
# |    critic_loss     | 0.285    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13041    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -46.1    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 192      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 13391    |
# | train/             |          |
# |    actor_loss      | 2.63     |
# |    critic_loss     | 0.631    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13241    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.7     |
# |    ep_rew_mean     | -45.6    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 191      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 13496    |
# | train/             |          |
# |    actor_loss      | 2.61     |
# |    critic_loss     | 0.652    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13395    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 191      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 13598    |
# | train/             |          |
# |    actor_loss      | 2.76     |
# |    critic_loss     | 0.315    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13497    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.2     |
# |    ep_rew_mean     | -45.1    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 192      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 13798    |
# | train/             |          |
# |    actor_loss      | 2.63     |
# |    critic_loss     | 0.374    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13648    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44.1    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 192      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 13900    |
# | train/             |          |
# |    actor_loss      | 2.95     |
# |    critic_loss     | 0.225    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13750    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 192      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 14100    |
# | train/             |          |
# |    actor_loss      | 2.59     |
# |    critic_loss     | 0.271    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13950    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44.1    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 192      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 14251    |
# | train/             |          |
# |    actor_loss      | 2.54     |
# |    critic_loss     | 0.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14101    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -44.1    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 192      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 14451    |
# | train/             |          |
# |    actor_loss      | 2.55     |
# |    critic_loss     | 0.522    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14301    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.3     |
# |    ep_rew_mean     | -43.1    |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 192      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 14557    |
# | train/             |          |
# |    actor_loss      | 2.54     |
# |    critic_loss     | 0.517    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14456    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.8     |
# |    ep_rew_mean     | -42.7    |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 193      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 14712    |
# | train/             |          |
# |    actor_loss      | 2.27     |
# |    critic_loss     | 0.308    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14562    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.3     |
# |    ep_rew_mean     | -42.2    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 193      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 14863    |
# | train/             |          |
# |    actor_loss      | 2.64     |
# |    critic_loss     | 0.543    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14713    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.8     |
# |    ep_rew_mean     | -41.7    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 193      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 15014    |
# | train/             |          |
# |    actor_loss      | 2.78     |
# |    critic_loss     | 0.477    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14864    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.8     |
# |    ep_rew_mean     | -41.7    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 192      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 15214    |
# | train/             |          |
# |    actor_loss      | 2.69     |
# |    critic_loss     | 0.402    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15064    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.8     |
# |    ep_rew_mean     | -41.7    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 192      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 15414    |
# | train/             |          |
# |    actor_loss      | 2.57     |
# |    critic_loss     | 0.744    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15264    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.8     |
# |    ep_rew_mean     | -41.7    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 192      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 15614    |
# | train/             |          |
# |    actor_loss      | 2.55     |
# |    critic_loss     | 0.568    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15464    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.8     |
# |    ep_rew_mean     | -41.7    |
# |    success_rate    | 0.17     |
# | time/              |          |
# ...
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 7.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144467   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.8     |
# |    ep_rew_mean     | -42.6    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 3268     |
# |    fps             | 197      |
# |    time_elapsed    | 734      |
# |    total_timesteps | 144768   |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 4.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144618   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.3     |
# |    ep_rew_mean     | -43.1    |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 3272     |
# |    fps             | 197      |
# |    time_elapsed    | 734      |
# |    total_timesteps | 144919   |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 2.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144769   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.2     |
# |    ep_rew_mean     | -43      |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 3276     |
# |    fps             | 197      |
# |    time_elapsed    | 735      |
# |    total_timesteps | 145061   |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 6.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144945   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.6     |
# |    ep_rew_mean     | -42.4    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 3280     |
# |    fps             | 197      |
# |    time_elapsed    | 736      |
# |    total_timesteps | 145207   |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 7.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 145084   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.6     |
# |    ep_rew_mean     | -42.4    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 3284     |
# |    fps             | 197      |
# |    time_elapsed    | 737      |
# |    total_timesteps | 145407   |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 7.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 145257   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | -42      |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 3288     |
# |    fps             | 197      |
# |    time_elapsed    | 738      |
# |    total_timesteps | 145563   |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 2.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 145413   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.5     |
# |    ep_rew_mean     | -42.4    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 3292     |
# |    fps             | 197      |
# |    time_elapsed    | 738      |
# |    total_timesteps | 145714   |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 9.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 145564   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.1     |
# |    ep_rew_mean     | -42      |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 3296     |
# |    fps             | 197      |
# |    time_elapsed    | 739      |
# |    total_timesteps | 145874   |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 8.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 145724   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.5     |
# |    ep_rew_mean     | -42.3    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 197      |
# |    time_elapsed    | 740      |
# |    total_timesteps | 146074   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 8.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 145924   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42       |
# |    ep_rew_mean     | -41.8    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 3304     |
# |    fps             | 197      |
# |    time_elapsed    | 741      |
# |    total_timesteps | 146225   |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 8.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146124   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.5     |
# |    ep_rew_mean     | -42.3    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 3308     |
# |    fps             | 140      |
# |    time_elapsed    | 1043     |
# |    total_timesteps | 146425   |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 7.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146275   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42       |
# |    ep_rew_mean     | -41.8    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 3312     |
# |    fps             | 140      |
# |    time_elapsed    | 1044     |
# |    total_timesteps | 146534   |
# | train/             |          |
# |    actor_loss      | -14.6    |
# |    critic_loss     | 9.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146384   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -41      |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 3316     |
# |    fps             | 140      |
# |    time_elapsed    | 1045     |
# |    total_timesteps | 146648   |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 8.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.1     |
# |    ep_rew_mean     | -40.9    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 3320     |
# |    fps             | 140      |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 146799   |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 8.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146698   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.1     |
# |    ep_rew_mean     | -40.9    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 3324     |
# |    fps             | 140      |
# |    time_elapsed    | 1047     |
# |    total_timesteps | 146999   |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 6.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146849   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -40      |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 3328     |
# |    fps             | 140      |
# |    time_elapsed    | 1047     |
# |    total_timesteps | 147109   |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 6.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40       |
# |    ep_rew_mean     | -39.8    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 3332     |
# |    fps             | 140      |
# |    time_elapsed    | 1048     |
# |    total_timesteps | 147260   |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 7.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147110   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 model.learn(total_timesteps=1e6)
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/stable_baselines3/ddpg/ddpg.py:123, in DDPG.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     114 def learn(
#     115     self: SelfDDPG,
#     116     total_timesteps: int,
#    (...)
#     121     progress_bar: bool = False,
#     122 ) -> SelfDDPG:
# --> 123     return super().learn(
#     124         total_timesteps=total_timesteps,
#     125         callback=callback,
#     126         log_interval=log_interval,
#     127         tb_log_name=tb_log_name,
#     128         reset_num_timesteps=reset_num_timesteps,
#     129         progress_bar=progress_bar,
#     130     )
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:194, in TD3.train(self, gradient_steps, batch_size)
#     191 # Delayed policy updates
#     192 if self._n_updates % self.policy_delay == 0:
#     193     # Compute actor loss
# --> 194     actor_loss = -self.critic.q1_forward(replay_data.observations, self.actor(replay_data.observations)).mean()
#     195     actor_losses.append(actor_loss.item())
#     197     # Optimize the actor
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/stable_baselines3/td3/policies.py:78, in Actor.forward(self, obs)
#      75 def forward(self, obs: th.Tensor) -> th.Tensor:
#      76     # assert deterministic, 'The TD3 actor only outputs deterministic actions'
#      77     features = self.extract_features(obs, self.features_extractor)
# ---> 78     return self.mu(features)
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Downloads/ComputationalRobotics/franka-pipeline/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
model.save('rl_models/ddpg_stablebaselines_agent')
policy = model.policy
policy.save("rl_policies/ddpg_policy_pandapush")

# %%
model = DDPG.load('rl_models/ddpg_stablebaselines_agent',env=env)

# %%
obs = env.reset()

images = []
for i in range(100):
    action, _states = model.predict(obs)
    obs = env.step(action)[0]
    img = env.render()
    img = PIL.Image.fromarray(img)
    images.append(img)
    print("Iteration: ",i)

env.close()
# Out:
# Iteration:  0
# Iteration:  1
# Iteration:  2
# Iteration:  3
# Iteration:  4
# Iteration:  5
# Iteration:  6
# Iteration:  7
# Iteration:  8
# Iteration:  9
# Iteration:  10
# Iteration:  11
# Iteration:  12
# Iteration:  13
# Iteration:  14
# Iteration:  15
# Iteration:  16
# Iteration:  17
# Iteration:  18
# Iteration:  19
# Iteration:  20
# Iteration:  21
# Iteration:  22
# Iteration:  23
# Iteration:  24
# Iteration:  25
# Iteration:  26
# Iteration:  27
# Iteration:  28
# Iteration:  29
# Iteration:  30
# Iteration:  31
# Iteration:  32
# Iteration:  33
# Iteration:  34
# Iteration:  35
# Iteration:  36
# Iteration:  37
# Iteration:  38
# Iteration:  39
# Iteration:  40
# Iteration:  41
# Iteration:  42
# Iteration:  43
# Iteration:  44
# Iteration:  45
# Iteration:  46
# Iteration:  47
# Iteration:  48
# Iteration:  49
# Iteration:  50
# Iteration:  51
# Iteration:  52
# Iteration:  53
# Iteration:  54
# Iteration:  55
# Iteration:  56
# Iteration:  57
# Iteration:  58
# Iteration:  59
# Iteration:  60
# Iteration:  61
# Iteration:  62
# Iteration:  63
# Iteration:  64
# Iteration:  65
# Iteration:  66
# Iteration:  67
# Iteration:  68
# Iteration:  69
# Iteration:  70
# Iteration:  71
# Iteration:  72
# Iteration:  73
# Iteration:  74
# Iteration:  75
# Iteration:  76
# Iteration:  77
# Iteration:  78
# Iteration:  79
# Iteration:  80
# Iteration:  81
# Iteration:  82
# Iteration:  83
# Iteration:  84
# Iteration:  85
# Iteration:  86
# Iteration:  87
# Iteration:  88
# Iteration:  89
# Iteration:  90
# Iteration:  91
# Iteration:  92
# Iteration:  93
# Iteration:  94
# Iteration:  95
# Iteration:  96
# Iteration:  97
# Iteration:  98
# Iteration:  99

# %%
images[0].save('gif/ddpg_stablebaselines_example.gif',
              save_all=True, append_images=images[1:],
              optimize=False, duration=40, loop=0)
