# %% [markdown]
# This notebook provides examples to go along with the [textbook](http://manipulation.csail.mit.edu/rl.html).  I recommend having both windows open, side-by-side!

# %%
import gymnasium as gym
import numpy as np
import torch
from psutil import cpu_count
from pydrake.all import StartMeshcat

import box_flipup  # no-member
from manipulation.meshcat_utils import plot_surface
#from manipulation.utils import FindDataResource, RenderDiagram, running_as_notebook
from utils import FindResource, running_as_notebook
num_cpu = int(cpu_count() / 2) if running_as_notebook else 2

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv

# %%
meshcat = StartMeshcat()
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7004

# %% [markdown]
# # RL for box flip-up
#
# ## State-feedback policy via PPO (with stiffness control)

# %%
observations = "state"
time_limit = 10 if running_as_notebook else 0.5

# Note: Models saved in stable baselines are version specific.  This one
# requires python3.8 (and cloudpickle==1.6.0).
zip = f"box_flipup_ppo_{observations}.zip"


# Use a callback so that the forked process imports the environment.
def make_boxflipup():
    import manipulation.envs.box_flipup

    return gym.make("BoxFlipUp-v0", observations=observations, time_limit=time_limit)


env = make_vec_env(
    make_boxflipup,
    n_envs=num_cpu,
    seed=0,
    vec_env_cls=SubprocVecEnv if running_as_notebook else DummyVecEnv,
)

use_pretrained_model = True
if use_pretrained_model:
    # TODO(russt): Save a trained model that works on Deepnote.
    model = PPO.load(FindResource(zip), env)
elif running_as_notebook:
    # This is a relatively small amount of training.  See rl/train_boxflipup.py
    # for a version that runs the heavyweight version with multiprocessing.
    model = PPO("MlpPolicy", env, verbose=1)
    model.learn(total_timesteps=100000)
else:
    # For testing this notebook, we simply want to make sure that the code runs.
    model = PPO("MlpPolicy", env, n_steps=4, n_epochs=2, batch_size=8)
    model.learn(total_timesteps=4)
# Out:
# Process ForkServerProcess-14:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-15:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-11:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-7:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-9:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-4:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-13:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-3:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-12:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-10:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-8:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-5:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[7], line 16
#      11     import manipulation.envs.box_flipup
#      13     return gym.make("BoxFlipUp-v0", observations=observations, time_limit=time_limit)
# ---> 16 env = make_vec_env(
#      17     make_boxflipup,
#      18     n_envs=num_cpu,
#      19     seed=0,
#      20     vec_env_cls=SubprocVecEnv if running_as_notebook else DummyVecEnv,
#      21 )
#      23 use_pretrained_model = True
#      24 if use_pretrained_model:
#      25     # TODO(russt): Save a trained model that works on Deepnote.
#
# File ~/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py:125, in make_vec_env(env_id, n_envs, seed, start_index, monitor_dir, wrapper_class, env_kwargs, vec_env_cls, vec_env_kwargs, monitor_kwargs, wrapper_kwargs)
#     121 if vec_env_cls is None:
#     122     # Default: use a DummyVecEnv
#     123     vec_env_cls = DummyVecEnv
# --> 125 vec_env = vec_env_cls([make_env(i + start_index) for i in range(n_envs)], **vec_env_kwargs)
#     126 # Prepare the seeds for the first reset
#     127 vec_env.seed(seed)
#
# File ~/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py:119, in SubprocVecEnv.__init__(self, env_fns, start_method)
#     116     work_remote.close()
#     118 self.remotes[0].send(("get_spaces", None))
# --> 119 observation_space, action_space = self.remotes[0].recv()
#     121 super().__init__(len(env_fns), observation_space, action_space)
#
# File /usr/lib/python3.12/multiprocessing/connection.py:250, in _ConnectionBase.recv(self)
#     248 self._check_closed()
#     249 self._check_readable()
# --> 250 buf = self._recv_bytes()
#     251 return _ForkingPickler.loads(buf.getbuffer())
#
# File /usr/lib/python3.12/multiprocessing/connection.py:430, in Connection._recv_bytes(self, maxsize)
#     429 def _recv_bytes(self, maxsize=None):
# --> 430     buf = self._recv(4)
#     431     size, = struct.unpack("!i", buf.getvalue())
#     432     if size == -1:
#
# File /usr/lib/python3.12/multiprocessing/connection.py:395, in Connection._recv(self, size, read)
#     393 remaining = size
#     394 while remaining > 0:
# --> 395     chunk = read(handle, remaining)
#     396     n = len(chunk)
#     397     if n == 0:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
# _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.
# Process ForkServerProcess-16:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_util.py", line 98, in _init
#     env = env_id(**env_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_491386/2212558267.py", line 13, in make_boxflipup
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/franka/Documents/franka-pipeline/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `BoxFlipUp` doesn't exist.

# %%
# Make a version of the env with meshcat.
env = gym.make("BoxFlipUp-v0", meshcat=meshcat, observations=observations)

obs, _ = env.reset()
meshcat.StartRecording()
for i in range(500 if running_as_notebook else 5):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    if terminated:
        obs, _ = env.reset()
meshcat.PublishRecording()

# %%
obs, _ = env.reset()
Q, Qdot = np.meshgrid(np.arange(0, np.pi, 0.05), np.arange(-2, 2, 0.05))
# TODO(russt): tensorize this...
V = 0 * Q
for i in range(Q.shape[0]):
    for j in range(Q.shape[1]):
        obs[2] = Q[i, j]
        obs[7] = Qdot[i, j]
        with torch.no_grad():
            V[i, j] = (
                model.policy.predict_values(model.policy.obs_to_tensor(obs)[0])[0]
                .cpu()
                .numpy()[0]
            )
V = V - np.min(np.min(V))
V = V / np.max(np.max(V))

meshcat.Delete()
meshcat.ResetRenderMode()
plot_surface(meshcat, "Critic", Q, Qdot, V, wireframe=True)

# %%
env = gym.make("BoxFlipUp-v0")

#RenderDiagram(env.simulator.get_system(), max_depth=1)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8ac7c900-70d2-4af1-83c6-341a64fb0e14' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
